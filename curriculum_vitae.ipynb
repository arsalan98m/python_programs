# %%
name = "Muhammad Arsalan Manzoor"
father_name = "Manzoor Ali"
date_of_birth = "16-11-1998"
address = "H# 31 Karachi."
phone_no = "0311-21219911"
email = "arsalan@gmail.com"
NIC = "42101-212191212-1"
Nationality = "Pakistani"
bold_start = '\033[1m'
bold_end = "\033[0;0m"
cv ="""
                         {}
  Personal Data:                                 
  ____________________________________________________________________  
  
  Father Name  : {}
  Date of Birth: {}
  Address      : {}
  Phone        : {}
  Email        : {}
  NIC          : {}
  Nationality  : {}
  
  Qualification: 
  ____________________________________________________________________
  
  Matric From SSC Board in 2016
  Intermediate From HSC Board in 2018
  
  Skills:
  ____________________________________________________________________
  
  (1) HTML
  (2) CSS
  (3) Python
  (4) Linux
  (5) Github
  
  Experience:
  ____________________________________________________________________
  
  7 Years working experience on Software Desktop Support
  1 Year Software Development Experience
  
  Languages:
  ____________________________________________________________________
  
  English
  Urdu
"""

print(cv.format(bold_start+name.title()+ bold_end,father_name,date_of_birth,address.title(),phone_no,email,NIC,Nationality))
# Out:
#                          Muhammad Arsalan Manzoor
#   Personal Data:
#   ____________________________________________________________________
#
#   Father Name  : Manzoor Ali
#   Date of Birth: 16-11-1998
#   Address      : H# 31 Karachi.
#   Phone        : 0311-21219911
#   Email        : arsalan@gmail.com
#   NIC          : 42101-212191212-1
#   Nationality  : Pakistani
#
#   Qualification:
#   ____________________________________________________________________
#
#   Matric From SSC Board in 2016
#   Intermediate From HSC Board in 2018
#
#   Skills:
#   ____________________________________________________________________
#
#   (1) HTML
#   (2) CSS
#   (3) Python
#   (4) Linux
#   (5) Github
#
#   Experience:
#   ____________________________________________________________________
#
#   7 Years working experience on Software Desktop Support
#   1 Year Software Development Experience
#
#   Languages:
#   ____________________________________________________________________
#
# ...
