# %%
questions = [
    {
        "Qno": 1,
        "question": "What is python?",
        "options": ["Interpreted language", "Compiled language", "Low-level language", "Assembly language"],
        "answer" : "1",
    },
    {
        "Qno": 2,
        "question": "Which one is NOT a legal variable name?",
        "options": ["my-var", "_myvar", "MYvar", "my_var"],
        "answer": "1",
    },
    {
        "Qno": 3,
        "question": "How do you create a variable with the numeric value 5?",
        "options": ["x = 5", "x = int(5)", "x = int('5')", "Both Correct"],
        "answer": "4",
    },
    {
        "Qno": 4,
        "question": "What is the correct file extension for python files?",
        "options": [".pt", ".pyth", ".py", ".pyt"],
        "answer": "3",
    },
    {
        "Qno": 5,
        "question": "What method can be used to remove any white space from both the beginnig and end of a string?",
        "options": ["ptrim()","strip()", "len()", "trim"],
        "answer": "2",
    }
]

# %%
score = 0

for question in questions:
    output_data = "\n\n"+str(question["Qno"]) + ": "+ question["question"] +"\n\n"+"Choose correct answer: "+"\n"+"1: "+question["options"][0] +"\n"+ "2: "+question["options"][1] + "\n" + "3: " +question["options"][2]+"\n"+"4: "+question["options"][3]
    answer = input(output_data)
    
    if answer == question['answer']:
        score +=1

# Score Condition
if score == 5:
    print("\n\nYour Score is: "+str(score))
    print("🎉🎉🍕 YOU WIN!!!! 🎉🎉🍕")
elif score == 3:
    print("\n\nYour Score is: "+str(score))
    print("😎Cool Keep learning")
else:
    print("\n\nYour Score is: "+str(score))
    print("Keep Practicing")

# Calculation marks
#total marks / obt * 100
percentage = score/5 * 100
print("Your Percentage is : "+str(percentage)+"%")
# Out:
# 1: What is python?
#
# Choose correct answer:
# 1: Interpreted language
# 2: Compiled language
# 3: Low-level language
# 4: Assembly language1
#
#
# 2: Which one is NOT a legal variable name?
#
# Choose correct answer:
# 1: my-var
# 2: _myvar
# 3: MYvar
# 4: my_var2
#
#
# 3: How do you create a variable with the numeric value 5?
#
# Choose correct answer:
# 1: x = 5
# 2: x = int(5)
# 3: x = int('5')
# 4: Both Correct3
#
#
# 4: What is the correct file extension for python files?
#
# Choose correct answer:
# 1: .pt
# 2: .pyth
# 3: .py
# 4: .pyt4
#
#
# 5: What method can be used to remove any white space from both the beginnig and end of a string?
#
# Choose correct answer:
# 1: ptrim()
# 2: strip()
# 3: len()
# 4: trim5
#
#
# Your Score is: 1
# Keep Practicing
# Your Percentage is : 20.0%
